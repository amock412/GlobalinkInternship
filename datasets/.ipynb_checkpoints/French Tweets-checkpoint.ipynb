# %%
import re
import tweepy
import pandas as pd

# %%
consumer_key = '2emKOn7yzDwfq8qPHPREetjLT'
consumer_secret = 'UT8zrTnYsbDEIKKT0GmkvajvqVD5SAVeYgYE0WqrqisAje3Yql'
access_token = '1304470646869680130-Svfvf1tiYHvafyrwSF1pjrv2w7kk28'
access_token_secret = 'rlGShOI3IKCj0lnatFgAST8AE8ET04RT3nQIwlv1s1Gvx'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
print(api)

# %%
def clean_tweet(self, tweet):
      # cleans tweet text by removing links and special characters
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def get_tweets(self, query, count = 10):
      tweets = []
      try:
         # call twitter api to fetch tweets
         fetched_tweets = self.api.search(q = query, count = count)
   
         # parsing tweets one by one
         for tweet in fetched_tweets:
            parsed_tweet = {}
            parsed_tweet['text'] = tweet.text
         if tweet.retweet_count > 0:   
            # ensure retweets is appended only once
            if parsed_tweet not in tweets:
               tweets.append(parsed_tweet)
         else:
            tweets.append(parsed_tweet)
     
         return tweets
      except tweepy.TweepError as e:
         print("Error : " + str(e))
def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    
    # calling function to get tweets
    tweets = api.get_tweets(query = 'SEARCH_KEY', count = 200)
if __name__ == "__main__":
    # calling main function
    main()

# %%
help(api)
# Out:
# Help on API in module tweepy.api object:
#
# class API(builtins.object)
#  |  API(auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |
#  |  Twitter API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |      API instance constructor
#  |
#  |      :param auth_handler:
#  |      :param host: url of the server of the rest api,
# ...

# %%
tweets = tweepy.Cursor(api.search, q="sale", lang="fr").items(1000)


# box Montreal'-73.9278,45.3983,-73.2861,45.6247'

# %%
# Store the tweets in a list
tweet_list = [tweet for tweet in tweets]

# %%
# dataframe to save tweets
db_tweets = pd.DataFrame(columns = ['username', 'acctdesc', 'location', 'following',
                                        'followers', 'totaltweets', 'usercreatedts', 'tweetcreatedts',
                                        'retweetcount', 'text', 'hashtags'])

# %%
for tweet in tweet_list[:500]:
# Pull the values
    username = tweet.user.screen_name
    acctdesc = tweet.user.description
    location = tweet.user.location
    following = tweet.user.friends_count
    followers = tweet.user.followers_count
    totaltweets = tweet.user.statuses_count
    usercreatedts = tweet.user.created_at
    tweetcreatedts = tweet.created_at
    retweetcount = tweet.retweet_count
    hashtags = tweet.entities['hashtags']         
    text = tweet.text
    
    ith_tweet = [username, acctdesc, location, following, followers, totaltweets,
                         usercreatedts, tweetcreatedts, retweetcount, text, hashtags]
    # Append to dataframe - db_tweets
    db_tweets.loc[len(db_tweets)] = ith_tweet

# %%
# filled dataframe
db_tweets
# Out:
#             username                                           acctdesc  \
# 0    laverit51598112                               Uniquement la vérité
# 1        2Neymarinho                               Neymarinho partie II
# 2         Misye_klod  WOW être père sa change la vie.👀👶🏽💞\n\nTwitter...
# 3           MastaNed                               Beriz-Beirut-NYC-Ldn
# 4    rocketracoonmvp                                     1m95 90kg 27cm
# ..               ...                                                ...
# 495        helinee_c
# 496         Delf2205  Il m' est égal de lire que les sables des plag...
# 497      Darealcrack               Djilobodji , Ride or die | Loyalty |
# 498         NeKrosrr   19y / earning 1200$ / Dbz GOAT\nAnti fan de jojo
# 499       _MonsieurB                                               🇨🇬🇨🇬
#
#                 location following followers totaltweets       usercreatedts  \
# ...

# %%
# Out:
# Help on User in module tweepy.models object:
#
# class User(Model)
#  |  User(api=None)
#  |
#  |  Method resolution order:
#  |      User
#  |      Model
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  follow(self)
#  |
#  |  followers(self, **kwargs)
#  |
#  |  followers_ids(self, *args, **kwargs)
#  |
#  |  friends(self, **kwargs)
#  |
#  |  lists(self, *args, **kwargs)
#  |
#  |  lists_memberships(self, *args, **kwargs)
#  |
#  |  lists_subscriptions(self, *args, **kwargs)
#  |
#  |  timeline(self, **kwargs)
#  |
#  |  unfollow(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  parse(api, json) from builtins.type
#  |      Parse a JSON object into a model instance.
#  |
#  |  parse_list(api, json_list) from builtins.type
# ...
