# %% [markdown]
# # French Tweets
# The summer project is related to social media comments surrounding urban infrastructure. The first exploration I did was just searching for certain key words on Twitter using the Twitter API. This is just playing around to see what data can be found via Twitter and how useful it may be in the future.

# %%
import re
import tweepy
import pandas as pd

# %%
consumer_key = '' # enter your information
consumer_secret = ''
access_token = ''
access_token_secret = ''
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
print(api)

# %%
def clean_tweet(tweet):
      # cleans tweet text by removing links and special characters
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
# search for tweets related to the word dirty in french 
tweets = tweepy.Cursor(api.search, q="sale", lang="fr").items(1000)


# box Montreal'-73.9278,45.3983,-73.2861,45.6247'

# %%
# Store the tweets in a list
tweet_list = [tweet for tweet in tweets]

# %%
# dataframe to save tweets
db_tweets = pd.DataFrame(columns = ['username', 'acctdesc', 'location', 'following',
                                        'followers', 'totaltweets', 'usercreatedts', 'tweetcreatedts',
                                        'retweetcount', 'text', 'hashtags'])

# %%
for tweet in tweet_list[:500]:
# Pull the values
    username = tweet.user.screen_name
    acctdesc = tweet.user.description
    location = tweet.user.location
    following = tweet.user.friends_count
    followers = tweet.user.followers_count
    totaltweets = tweet.user.statuses_count
    usercreatedts = tweet.user.created_at
    tweetcreatedts = tweet.created_at
    retweetcount = tweet.retweet_count
    hashtags = tweet.entities['hashtags']         
    text = tweet.text
    
    ith_tweet = [username, acctdesc, location, following, followers, totaltweets,
                         usercreatedts, tweetcreatedts, retweetcount, text, hashtags]
    # Append to dataframe - db_tweets
    db_tweets.loc[len(db_tweets)] = ith_tweet

# %%
# filled dataframe
db_tweets
# Out:
#             username                                           acctdesc  \
# 0    laverit51598112                               Uniquement la vérité
# 1        2Neymarinho                               Neymarinho partie II
# 2         Misye_klod  WOW être père sa change la vie.👀👶🏽💞\n\nTwitter...
# 3           MastaNed                               Beriz-Beirut-NYC-Ldn
# 4    rocketracoonmvp                                     1m95 90kg 27cm
# ..               ...                                                ...
# 495        helinee_c
# 496         Delf2205  Il m' est égal de lire que les sables des plag...
# 497      Darealcrack               Djilobodji , Ride or die | Loyalty |
# 498         NeKrosrr   19y / earning 1200$ / Dbz GOAT\nAnti fan de jojo
# 499       _MonsieurB                                               🇨🇬🇨🇬
#
#                 location following followers totaltweets       usercreatedts  \
# ...

# %%
# search for tweets related to the keyword montreal
tweets2 = tweepy.Cursor(api.search, q="Montreal", lang="fr").items(200)

# %%
# Store the tweets in a list
tweet_list2 = [tweet for tweet in tweets2]

# %%
# dataframe to save tweets
montreal_tweets = pd.DataFrame(columns = ['username', 'acctdesc', 'location', 'following',
                                        'followers', 'totaltweets', 'usercreatedts', 'tweetcreatedts',
                                        'retweetcount', 'text', 'hashtags'])

# %%
for tweet in tweet_list2:
# Pull the values
    username = tweet.user.screen_name
    acctdesc = tweet.user.description
    location = tweet.user.location
    following = tweet.user.friends_count
    followers = tweet.user.followers_count
    totaltweets = tweet.user.statuses_count
    usercreatedts = tweet.user.created_at
    tweetcreatedts = tweet.created_at
    retweetcount = tweet.retweet_count
    hashtags = tweet.entities['hashtags']         
    text = tweet.text
    
    ith_tweet = [username, acctdesc, location, following, followers, totaltweets,
                         usercreatedts, tweetcreatedts, retweetcount, text, hashtags]
    # Append to dataframe - db_tweets
    montreal_tweets.loc[len(montreal_tweets)] = ith_tweet

# %%
montreal_tweets
# Out:
#             username                                           acctdesc  \
# 0        Toutunmatin  Émission matinale d'ICI Radio-Canada Première ...
# 1            danipoi
# 2        Toutunmatin  Émission matinale d'ICI Radio-Canada Première ...
# 3        Toutunmatin  Émission matinale d'ICI Radio-Canada Première ...
# 4    TrafficMontreal                       Traffic updates for Montreal
# ..               ...                                                ...
# 195          swtyglo
# 196         jobWings  A specialized niche site dedicated to the publ...
# 197        Espace_CH  @LeMagAllHabs / @lehockeyherald / @lebloguehoc...
# 198       crisbove88
# 199    MyTransit_MTL  Latest Montreal #Transportation news covering ...
#
#                location following followers totaltweets       usercreatedts  \
# 0                              42      4385        3934 2019-08-06 17:33:35
# 1                Ottawa      1098       100         580 2009-09-16 02:49:35
# ...

# %%
montreal_tweets[montreal_tweets['username'] == 'TrafficMontreal']
# Out:
#            username                      acctdesc  location following  \
# 4   TrafficMontreal  Traffic updates for Montreal  Montreal        11
# 5   TrafficMontreal  Traffic updates for Montreal  Montreal        11
# 18  TrafficMontreal  Traffic updates for Montreal  Montreal        11
# 20  TrafficMontreal  Traffic updates for Montreal  Montreal        11
# 43  TrafficMontreal  Traffic updates for Montreal  Montreal        11
#
#    followers totaltweets       usercreatedts      tweetcreatedts retweetcount  \
# 4       3291      513224 2009-09-15 14:42:45 2021-06-18 10:22:02            0
# 5       3291      513224 2009-09-15 14:42:45 2021-06-18 10:21:50            0
# 18      3291      513224 2009-09-15 14:42:45 2021-06-18 10:12:47            0
# 20      3291      513224 2009-09-15 14:42:45 2021-06-18 10:12:03            0
# 43      3291      513224 2009-09-15 14:42:45 2021-06-18 09:41:48            0
#
#                                                  text hashtags
# ...

# %%
montreal_tweets[montreal_tweets['username'] == 'TrafficMontreal']['text'][4]
# Out:
# "Montréal - westbound Métropolitaine/Metropolitan between Blvd L'acadie and Boul Decarie slow traffic"

# %%
# tweets by one particular user
montreal_tweets[montreal_tweets['username'] == 'MyTransit_MTL']
# Out:
#           username                                           acctdesc  \
# 87   MyTransit_MTL  Latest Montreal #Transportation news covering ...
# 109  MyTransit_MTL  Latest Montreal #Transportation news covering ...
# 128  MyTransit_MTL  Latest Montreal #Transportation news covering ...
# 199  MyTransit_MTL  Latest Montreal #Transportation news covering ...
#
#              location following followers totaltweets       usercreatedts  \
# 87   Montréal, Québec       120       229        6065 2017-07-16 04:56:38
# 109  Montréal, Québec       120       229        6065 2017-07-16 04:56:38
# 128  Montréal, Québec       120       229        6065 2017-07-16 04:56:38
# 199  Montréal, Québec       120       229        6065 2017-07-16 04:56:38
#
#          tweetcreatedts retweetcount  \
# 87  2021-06-18 07:53:07            0
# 109 2021-06-18 06:53:36            0
# 128 2021-06-18 05:53:15            0
# 199 2021-06-18 03:53:17            0
#
# ...

# %%
montreal_tweets[montreal_tweets['username'] == 'MyTransit_MTL']['text'][109]
# Out:
# 'Réseau structurant à Lachine: pas nécessairement un tramway - TVA Nouvelles: https://t.co/JT813V7vLU #STMInfo… https://t.co/LWCvxr4qlQ'
